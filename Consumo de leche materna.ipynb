# %% [markdown]
# # Consumo de leche materna
# * Isabella Terrel Jiménez (F. Nacimiento: 15/02/2022)
# * La data se registró finalizando la 1ra semana (del 20/02 al 05/03)

# %% [markdown]
# ## 1ra semana 😍 👶🏻

# %%
import os
os.getcwd()
os.chdir('C:/Users/caleb.terrel/Desktop/caleb/Isabella Terrel/notebook')

# %%
from IPython.display import Image
Image(filename = 'Isabella1_2.jpg', width = 350, height = 350)

# %% [markdown]
# ## Importando los datos 👀
# * Los datos se registraron manualmente en Excel

# %%
Image(filename = 'Isabella3_2.jpg', width = 300, height = 300)

# %%
import pandas as pd

# %%
df = pd.read_excel('Consumo de leche materna.xlsx')
df.head()
# Out:
#    semana      fecha hra inicio   hra fin        fecha y hora  time  \
# 0       1 2022-02-20        NaN  03:15:00 2022-02-20 03:15:00     1
# 1       1 2022-02-20        NaN  07:10:00 2022-02-20 07:10:00     2
# 2       1 2022-02-20        NaN  10:10:00 2022-02-20 10:10:00     3
# 3       1 2022-02-20        NaN  14:10:00 2022-02-20 14:10:00     4
# 4       1 2022-02-20        NaN  18:10:00 2022-02-20 18:10:00     5
#
#    leche materna, oz  formula, oz  total
# 0                1.0          1.0    2.0
# 1                NaN          2.0    2.0
# 2                1.0          1.5    2.5
# 3                1.0          1.5    2.5
# 4                1.0          1.0    2.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   semana             103 non-null    int64
#  1   fecha              103 non-null    datetime64[ns]
#  2   hra inicio         10 non-null     object
#  3   hra fin            103 non-null    object
#  4   fecha y hora       103 non-null    datetime64[ns]
#  5   time               103 non-null    int64
#  6   leche materna, oz  92 non-null     float64
#  7   formula, oz        26 non-null     float64
#  8   total              103 non-null    float64
# dtypes: datetime64[ns](2), float64(3), int64(2), object(2)
# memory usage: 7.4+ KB

# %%
df[['leche materna, oz', 'formula, oz']] = df[['leche materna, oz', 'formula, oz']].fillna(0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   semana             103 non-null    int64
#  1   fecha              103 non-null    datetime64[ns]
#  2   hra inicio         10 non-null     object
#  3   hra fin            103 non-null    object
#  4   fecha y hora       103 non-null    datetime64[ns]
#  5   time               103 non-null    int64
#  6   leche materna, oz  103 non-null    float64
#  7   formula, oz        103 non-null    float64
#  8   total              103 non-null    float64
# dtypes: datetime64[ns](2), float64(3), int64(2), object(2)
# memory usage: 7.4+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# ## Visualización del consumo 📈

# %%
Image(filename = 'Isabella4_2.jpg', width = 300, height = 300)

# %% [markdown]
# ## Consumo a demanda. Onzas totales 🍼

# %%
# plt.rcParams['figure.figsize'] = (6.4, 4.8)
plt.rcParams['figure.figsize'] = (16, 5)

sb.set_theme()
sb.lineplot(x = "fecha y hora", y = "total", data = df, color = 'black')
plt.ylabel('oz totales')
# Out:
# Text(0, 0.5, 'oz totales')

# %% [markdown]
# ## Consumo a demanda. Onzas de leche materna y/o fórmula 🍼
#
# * En la 1ra semana tuvimos que darle fórmula por la baja producción de leche de mi hermosa esposa, pero gracias a Dios la producción de leche fue incrementándose, dejando de lado la fórmula! (seguimos en la batalla 💪)

# %%
#sb.set_theme()
sb.lineplot(x = "fecha y hora", y = "leche materna, oz", data = df, label = 'leche materna, oz')
sb.lineplot(x = "fecha y hora", y = "formula, oz", data = df, label = 'formula, oz')
plt.ylabel('oz')
# Out:
# Text(0, 0.5, 'oz')

# %% [markdown]
# ## Incremento % de consumo en las 2 últimas semanas: 31% 💪

# %%
df1 = df.groupby(by='semana')['total'].mean()
df1
# Out:
# semana
# 1    2.142857
# 2    2.142857
# 3    2.807692
# Name: total, dtype: float64

# %%
df1[3]/df1[2]-1
# Out:
# 0.31025641025641026

# %% [markdown]
# ## 3ra semana 😍 👶🏻

# %%
Image(filename = 'Isabella5_2.jpg', width = 400, height = 400)
